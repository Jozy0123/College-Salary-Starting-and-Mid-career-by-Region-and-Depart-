# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
degree = pd.read_csv('degrees-that-pay-back.csv')
salary = pd.read_csv('salaries-by-college-type.csv')
region = pd.read_csv('salaries-by-region.csv')

# %%
degree.sort_values('Mid-Career Median Salary', ascending=False).head(20)
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 8                   Chemical Engineering                 63200.0
# 12                  Computer Engineering                 61400.0
# 19                Electrical Engineering                 60900.0
# 1                  Aerospace Engineering                 57700.0
# 17                             Economics                 50100.0
# 44                               Physics                 50300.0
# 13                      Computer Science                 55900.0
# 30                Industrial Engineering                 57700.0
# 38                Mechanical Engineering                 57900.0
# 37                                  Math                 45400.0
# 43                   Physician Assistant                 74300.0
# 10                     Civil Engineering                 53900.0
# 14                          Construction                 53700.0
# 22                               Finance                 47900.0
# 35  Management Information Systems (MIS)                 49200.0
# 42                            Philosophy                 39900.0
# 33               International Relations                 40900.0
# 9                              Chemistry                 42600.0
# 36                             Marketing                 40800.0
# 25                               Geology                 43500.0
#
#     Mid-Career Median Salary  \
# 8                   107000.0
# 12                  105000.0
# 19                  103000.0
# 1                   101000.0
# 17                   98600.0
# 44                   97300.0
# 13                   95500.0
# 30                   94700.0
# 38                   93600.0
# 37                   92400.0
# 43                   91700.0
# 10                   90500.0
# 14                   88900.0
# 22                   88300.0
# 35                   82300.0
# 42                   81200.0
# 33                   80900.0
# 9                    79900.0
# 36                   79600.0
# 25                   79500.0
#
#     Percent change from Starting to Mid-Career Salary  \
# 8                                                69.3
# 12                                               71.0
# 19                                               69.1
# 1                                                75.0
# 17                                               96.8
# 44                                               93.4
# 13                                               70.8
# 30                                               64.1
# 38                                               61.7
# 37                                              103.5
# 43                                               23.4
# 10                                               67.9
# 14                                               65.5
# 22                                               84.3
# 35                                               67.3
# 42                                              103.5
# 33                                               97.8
# 9                                                87.6
# 36                                               95.1
# 25                                               82.8
#
#     Mid-Career 10th Percentile Salary  Mid-Career 25th Percentile Salary  \
# 8                             71900.0                            87300.0
# 12                            66100.0                            84100.0
# 19                            69300.0                            83800.0
# 1                             64300.0                            82100.0
# 17                            50600.0                            70600.0
# 44                            56000.0                            74200.0
# 13                            56000.0                            74900.0
# 30                            57100.0                            72300.0
# 38                            63700.0                            76200.0
# 37                            45200.0                            64200.0
# 43                            66400.0                            75200.0
# 10                            63400.0                            75100.0
# 14                            56300.0                            68100.0
# 22                            47200.0                            62100.0
# 35                            45300.0                            60500.0
# 42                            35500.0                            52800.0
# 33                            38200.0                            56000.0
# 9                             45300.0                            60700.0
# 36                            42100.0                            55600.0
# 25                            45000.0                            59600.0
#
#     Mid-Career 75th Percentile Salary  Mid-Career 90th Percentile Salary
# 8                            143000.0                           194000.0
# 12                           135000.0                           162000.0
# 19                           130000.0                           168000.0
# 1                            127000.0                           161000.0
# 17                           145000.0                           210000.0
# 44                           132000.0                           178000.0
# 13                           122000.0                           154000.0
# 30                           132000.0                           173000.0
# 38                           120000.0                           163000.0
# 37                           128000.0                           183000.0
# 43                           108000.0                           124000.0
# 10                           115000.0                           148000.0
# 14                           118000.0                           171000.0
# 22                           128000.0                           195000.0
# 35                           108000.0                           146000.0
# 42                           127000.0                           168000.0
# 33                           111000.0                           157000.0
# 9                            108000.0                           148000.0
# 36                           119000.0                           175000.0
# 25                           101000.0                           156000.0

# %%
salary.sort_values('Mid-Career Median Salary', ascending=False).head(10)
# Out:
#                                      School Name  School Type  \
# 86                             Dartmouth College   Ivy League
# 87                          Princeton University   Ivy League
# 0    Massachusetts Institute of Technology (MIT)  Engineering
# 88                               Yale University   Ivy League
# 89                            Harvard University   Ivy League
# 1       California Institute of Technology (CIT)  Engineering
# 2                            Harvey Mudd College  Engineering
# 90                    University of Pennsylvania   Ivy League
# 4                                   Cooper Union  Engineering
# 3   Polytechnic University of New York, Brooklyn  Engineering
#
#     Starting Median Salary  Mid-Career Median Salary  \
# 86                 58000.0                  134000.0
# 87                 66500.0                  131000.0
# 0                  72200.0                  126000.0
# 88                 59100.0                  126000.0
# 89                 63400.0                  124000.0
# 1                  75500.0                  123000.0
# 2                  71800.0                  122000.0
# 90                 60900.0                  120000.0
# 4                  62200.0                  114000.0
# 3                  62400.0                  114000.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 25th Percentile Salary  \
# 86                            63100.0                            90200.0
# 87                            68900.0                           100000.0
# 0                             76800.0                            99200.0
# 88                            58000.0                            80600.0
# 89                            54800.0                            86200.0
# 1                                 NaN                           104000.0
# 2                                 NaN                            96000.0
# 90                            55900.0                            79200.0
# 4                                 NaN                            80200.0
# 3                             66800.0                            94300.0
#
#     Mid-Career 75th Percentile Salary  Mid-Career 90th Percentile Salary
# 86                           234000.0                           321000.0
# 87                           190000.0                           261000.0
# 0                            168000.0                           220000.0
# 88                           198000.0                           326000.0
# 89                           179000.0                           288000.0
# 1                            161000.0                                NaN
# 2                            180000.0                                NaN
# 90                           192000.0                           282000.0
# 4                            142000.0                                NaN
# 3                            143000.0                           190000.0

# %%
def change_to_num(money):
    if type(money)== str and money[0] == '$':
        a = money[1:].replace(',','')
        return float(a)
    else:
        return money
type(change_to_num('$234,54.00'))
# Out:
# float

# %%
degree = degree.applymap(change_to_num)

# %%
salary = salary.applymap(change_to_num)
region = region.applymap(change_to_num)

# %%
sns.barplot(y = 'Undergraduate Major', x = 'Percent change from Starting to Mid-Career Salary', data = degree.sort_values('Percent change from Starting to Mid-Career Salary', ascending= False))
fig = plt.gcf()
fig.set_size_inches(15, 20)

# %%
sns.barplot(y = 'Undergraduate Major', x = 'Starting Median Salary', data = degree.sort_values('Starting Median Salary'))
fig = plt.gcf()
fig.set_size_inches(15, 20)

# %%
b = sns.barplot(y = 'Undergraduate Major', x = 'Mid-Career Median Salary', data = degree.sort_values('Mid-Career Median Salary'))
fig_1 = plt.gcf()
fig_1.set_size_inches(15, 20)

# %%
salary.groupby('School Type').mean().plot(kind = 'bar')

# %%
region.groupby('Region').mean().plot(kind = 'bar')
